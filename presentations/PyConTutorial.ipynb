# %%
cd timgs
# Out:
# /home/kscottz/SimpleCVEducation/simplecv-examples/presentations/timgs

# %%
img1=Image('helloworld.jpg')
img2=Image('http://farm1.staticflickr.com/194/472097903_b781a0f4f8_z_d.jpg')
img1.show()
Most functionality lives in the image class.img2.show()
# Out:
# <SimpleCV.Display Object resolution:((640, 480)), Image Resolution: (0, 0) at memory location: (0x4216830)>

# %%
img3 = Image('simplecv')
img4 = Image('lenna')
img3.show()
img4.show()
# Out:
# <SimpleCV.Display Object resolution:((640, 480)), Image Resolution: (0, 0) at memory location: (0x459c1b8)>

# %%
# Out:
# {}

# %%
# Out:
# '/tmp/tmpTXzIN1.png'

# %%
# Out:
# helloworld.jpg  #references.txt#
